# %%
#import Basic Libraries

import numpy as np
import pandas as pd

# %%
#load the data

data=pd.read_csv("train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Basic Checks

# %%
#Shape:It is used to find no of rows and no of columns in a data
data.shape
# Out:
# (891, 12)

# %%
#head:it is used to print the first 5 rows
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# tail: it is used to print last 5 rows
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# print all the colummns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#To check the datatype of each column
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#info:it gives the information about data,missing values,datatype and memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#describe:it is used to do the statiscal values(mean.median,mode.....) --it is only applicable for numerical data

data.describe() #numerical data
data.describe().T # swaps rows <--->to column
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# Statiscal Analysis for categorical data
data.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# to fetch numerical columns
data.select_dtypes(include=["int64","float64"])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#to fetch categorical columns
data.select_dtypes(include="object")
data.select_dtypes(include="object").columns #if want only columns names
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# unique:it is used to find the unique categories in data
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#value_counts:it is used to find the count of unique categories
data.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data.Survived.unique()
# Out:
# array([0, 1])

# %%
data.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# how to checck the missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# how to create a copy of data
data1=data.copy()

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Create New Column

data1['Family']=data1['SibSp']+data1['Parch']
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Family'],
#       dtype='object')

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1['course']="Data Science"
data1.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family        course
# 0      0  A/5 21171   7.2500   NaN        S       1  Data Science
# 1      0   PC 17599  71.2833   C85        C       1  Data Science

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Remove the columns:
#axis =1 is used when we do any column manipulation
#axis=0 is used when we do any row manipulation
data1.drop("course",axis=1,inplace=True)

# %%
data1.head()
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# droping Multiple columns
#drop SibSp & Parch columns


data1.drop(['SibSp','Parch' ],axis =1 ,inplace=True)

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Family'],
#       dtype='object')

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
##Type Casting:converting one data type to other
## type casting will not work when there are missign values
# object(string values) cant be converted into int or float values
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Family           int64
# dtype: object

# %%
# converting fare float64 data to int32
# data1['Fare']=data1['Fare'].astype("int32")
#or
data1["Fare"] =data1.Fare.astype("int32")

# %%
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# Ticket          object
# Fare             int32
# Cabin           object
# Embarked        object
# Family         float64
# dtype: object

# %%
#converting family data
data1["Family"]=data1.Family.astype("float64")

# %%
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# Ticket          object
# Fare             int32
# Cabin           object
# Embarked        object
# Family         float64
# dtype: object

# %%
#Rename columns:
#Rename Age-->AGE,Cabin-->CABIN,Fare-->FARE

data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Family'],
#       dtype='object')

# %%
data1.rename(columns={"Age":"AGE","Cabin":"CABIN","Fare":"FARE"},inplace=True)

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'AGE', 'Ticket',
#        'FARE', 'CABIN', 'Embarked', 'Family'],
#       dtype='object')

# %%
# Sort the data based on fare
data1.sort_values("FARE",ascending=False)
data1.sort_values("Name",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 868          869         0       3            van Melkebeke, Mr. Philemon
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 286          287         1       3                de Mulder, Mr. Theodore
# ..           ...       ...     ...                                    ...
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 308          309         0       2                    Abelson, Mr. Samuel
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 845          846         0       3                    Abbing, Mr. Anthony
#
#         Sex   AGE         Ticket  FARE CABIN Embarked  Family
# ...

# %%
#Filter Data

#fetch  details related to female passenger

data.loc[data['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#fetch  details related to male passenger

data.loc[data['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#find how many passengers age is above 65
data.loc[data['Age']>65]

# data.loc[data['Age']>65].shape
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
#how many passengers are kids(with a age below 10)
data.loc[data['Age'] < 10]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
# fins how many passengers are there with an age less than 30

data.loc[(data['Sex']=='female') & (data['Age'] < 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#find how many passegers are travelling with age greather than 60 and lessthan 10 years

data.loc[(data['Age']<10) | (data['Age'] > 60)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 33            34         0       2                    Wheadon, Mr. Edward H
# ..           ...       ...     ...                                      ...
# 831          832         1       2          Richards, Master. George Sibley
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
#
# ...

# %%
# how to handle the missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.Age.dtypes
# Out:
# dtype('float64')

# %%
data.Cabin.dtypes
# Out:
# dtype('O')

# %%
data.Embarked.dtypes
# Out:
# dtype('O')

# %%
import seaborn as sns
sns.histplot(x=data.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#since distribution of AGe right skewed,we used median to replace the missing values in age column
data['Age'].median()
# Out:
# 28.0

# %%
data.loc[data['Age'].isnull()==True,'Age']=data['Age'].median()
#Age null value is replaced with median values
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
#Cabin
# when it is categorical data use mode
# data['Cabin'].mode()
data.loc[data['Cabin'].isnull()==True,"Cabin"]="G6"

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
#Embarked
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data.loc[data['Embarked'].isnull()==True,'Embarked']="S"

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Combining Data Frames

df1=pd.DataFrame({
    'A1':['A0','A1','A2','A3','A4','A5'],
    'B1':['B0','B1','B2','B3','B4','B5'],
    'C1':['C0','C1','C2','C3','C4','C5'],
    'D1':['D0','D1','D2','D3','D4','D5']})

# %%
df1
# Out:
#    A1  B1  C1  D1
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5

# %%
df2=pd.DataFrame({
    'A1':['A0','A1','A2','A3','A4','A5'],
    'B1':['B0','B1','B2','B3','B4','B5'],
    'C1':['C0','C1','C2','C3','C4','C5'],
    'D1':['D0','D1','D2','D3','D4','D5']})

# %%
df2
# Out:
#    A1  B1  C1  D1
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#     A1  B1  C1  D1
# 0   A0  B0  C0  D0
# 1   A1  B1  C1  D1
# 2   A2  B2  C2  D2
# 3   A3  B3  C3  D3
# 4   A4  B4  C4  D4
# 5   A5  B5  C5  D5
# 6   A0  B0  C0  D0
# 7   A1  B1  C1  D1
# 8   A2  B2  C2  D2
# 9   A3  B3  C3  D3
# 10  A4  B4  C4  D4
# 11  A5  B5  C5  D5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    A1  B1  C1  D1  A1  B1  C1  D1
# 0  A0  B0  C0  D0  A0  B0  C0  D0
# 1  A1  B1  C1  D1  A1  B1  C1  D1
# 2  A2  B2  C2  D2  A2  B2  C2  D2
# 3  A3  B3  C3  D3  A3  B3  C3  D3
# 4  A4  B4  C4  D4  A4  B4  C4  D4
# 5  A5  B5  C5  D5  A5  B5  C5  D5
